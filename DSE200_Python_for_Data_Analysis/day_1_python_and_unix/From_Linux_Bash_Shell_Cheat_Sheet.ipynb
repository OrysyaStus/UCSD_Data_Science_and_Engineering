# %%
# %cd ~/Documents/DSE/DSE200-notebooks/
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks

# %%
# !ls -a
#lists all files and folders
# Out:
# .     day_1_python_and_unix	    day_4_OOP_and_matplotlib	 README.md
# ..    day_2_github_io_numpy_pandas  day_5_mining_the_Social_web
# data  day_3_models_and_learning     .git

# %%
# !ls ./day_1_python_and_unix
#lists files in folder
# Out:
# 1_pregnancy_length_analysis.ipynb	    5_unix_exercises.ipynb
# 2_python_basics.ipynb			    5_unix_exercises_solutions.ipynb
# 3_python_basics_excercises.ipynb	    8queen.jpg
# 3_python_basics_excercises_solutions.ipynb  LockFile.md
# 4_unix,_sys,_and_os.ipynb

# %%
# !ls -lh
#detailed list, human readable
# Out:
# total 28K
# drwxrwxr-x 8 orysya orysya 4.0K Oct 29 12:01 data
# drwxrwxr-x 3 orysya orysya 4.0K Oct 29 12:01 day_1_python_and_unix
# drwxrwxr-x 5 orysya orysya 4.0K Oct 29 12:01 day_2_github_io_numpy_pandas
# drwxrwxr-x 4 orysya orysya 4.0K Oct 29 13:42 day_3_models_and_learning
# drwxrwxr-x 4 orysya orysya 4.0K Oct 29 12:01 day_4_OOP_and_matplotlib
# drwxrwxr-x 6 orysya orysya 4.0K Oct 29 12:01 day_5_mining_the_Social_web
# -rw-rw-r-- 1 orysya orysya  340 Oct 29 12:01 README.md

# %%
# !ls -l *.md
#list only .md files
# Out:
# -rw-rw-r-- 1 orysya orysya 340 Oct 29 12:01 README.md

# %%
# %cd /
#go to root ie. C:\
# Out:
# /

# %%
# %cd <data>
#change directory
# Out:
# [Errno 2] No such file or directory: '<data>'
# /

# %%
# !du -h
#disk usage of folders, human readable
# Out:
# 104K	./day_1_python_and_unix/.ipynb_checkpoints
# 584K	./day_1_python_and_unix
# 3.4M	./day_3_models_and_learning/.ipynb_checkpoints
# 612K	./day_3_models_and_learning/linalg
# 15M	./day_3_models_and_learning
# 300K	./day_5_mining_the_Social_web/images
# 2.1M	./day_5_mining_the_Social_web/ipynb/images
# 8.0K	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/appc-pythontips
# 8.0K	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch08-semanticweb
# 4.0K	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch09-twittercookbook
# 20K	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch04-googleplus/viz
# 24K	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch04-googleplus
# 26M	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch06-mailboxes/data
# 26M	./day_5_mining_the_Social_web/ipynb/Minining_the_social_web/resources/ch06-mailboxes
# ...

# %%
# !du -ah
#disk usage of files & folders, human readable
# Out:
# 8.0K	./day_1_python_and_unix/.ipynb_checkpoints/3_python_basics_excercises-checkpoint.ipynb
# 36K	./day_1_python_and_unix/.ipynb_checkpoints/2_python_basics-checkpoint.ipynb
# 16K	./day_1_python_and_unix/.ipynb_checkpoints/1_pregnancy_length_analysis-checkpoint.ipynb
# 8.0K	./day_1_python_and_unix/.ipynb_checkpoints/5_unix_exercises-checkpoint.ipynb
# 32K	./day_1_python_and_unix/.ipynb_checkpoints/4_unix,_sys,_and_os-checkpoint.ipynb
# 104K	./day_1_python_and_unix/.ipynb_checkpoints
# 4.0K	./day_1_python_and_unix/LockFile.md
# 8.0K	./day_1_python_and_unix/5_unix_exercises.ipynb
# 8.0K	./day_1_python_and_unix/.DS_Store
# 12K	./day_1_python_and_unix/8queen.jpg
# 16K	./day_1_python_and_unix/5_unix_exercises_solutions.ipynb
# 16K	./day_1_python_and_unix/3_python_basics_excercises.ipynb
# 4.0K	./day_1_python_and_unix/._.DS_Store
# 44K	./day_1_python_and_unix/3_python_basics_excercises_solutions.ipynb
# 36K	./day_1_python_and_unix/4_unix,_sys,_and_os.ipynb
# ...

# %%
# !du -sh
#only show disc usage of folders
# Out:
# 312M	.

# %%
# !pwd
#print working directory
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks

# %%
# !man echo
#shows manual (RTFM)
# Out:
# ECHO(1)                          User Commands                         ECHO(1)
#
# E
#        echo - display a line of text
#
# S
# G]...
# N
#
# N
#        Echo the STRING(s) to standard output.
#
# n     do not output the trailing newline
#
# e     enable interpretation of backslash escapes
#
# E     disable interpretation of backslash escapes (default)
#
# p display this help and exit
#
# n
#               output version information and exit
#
# e is in effect, the following sequences are recognized:
#
#        \\     backslash
#
#        \a     alert (BEL)
#
#        \b     backspace
#
#        \c     produce no further output
#
#        \e     escape
#
#        \f     form feed
#
#        \n     new line
#
#        \r     carriage return
#
#        \t     horizontal tab
#
#        \v     vertical tab
#
#        \0NNN  byte with octal value NNN (1 to 3 digits)
#
#        \xHH   byte with hexadecimal value HH (1 to 2 digits)
#
# ...

# %%
# %cd ./data/NLTK/Chopped/
# !ls -a
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped
# .     F112  F128  F142	F159  F174  F190  F205	F221  F26  F40	F56  F70  F85
# ..    F113  F129  F144	F16   F175  F191  F206	F222  F27  F41	F57  F71  F86
# F0    F114  F13   F145	F160  F176  F192  F207	F223  F28  F42	F58  F72  F87
# F1    F115  F130  F146	F161  F177  F193  F208	F224  F29  F43	F59  F73  F88
# F10   F117  F131  F147	F162  F178  F194  F209	F225  F3   F44	F6   F74  F9
# F100  F118  F132  F148	F163  F179  F195  F210	F226  F30  F45	F60  F75  F90
# F101  F119  F133  F149	F164  F18   F196  F211	F227  F31  F46	F61  F76  F91
# F102  F12   F134  F15	F165  F180  F197  F212	F228  F32  F48	F62  F77  F93
# F104  F120  F135  F151	F166  F181  F198  F213	F229  F33  F49	F63  F78  F94
# F106  F121  F136  F152	F167  F182  F199  F214	F23   F34  F5	F64  F79  F95
# F107  F122  F137  F153	F168  F183  F2	  F215	F230  F35  F50	F65  F8   F96
# F108  F123  F138  F154	F169  F185  F20   F216	F231  F36  F51	F66  F80  F97
# ...

# %%
# !cat F0
#show content of file
# Out:
#   669  681 received ''

# %%
# !head -8 F0
#from the top, show the first 8 lines
# Out:
#   669  681 received ''

# %%
# !tail -8 Word_List_sorted.csv
#from the bottom, show the last 8 lines
# Out:
# to
# up
# up
# up
# warm
# was
# way
# wind

# %%
# !mkdir cool
# %cd ./cool/
# !ls -a
#make a new directory within the folder
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped/cool
# .  ..

# %%
# %cd ..
# !cp F0 ./cool/
#copy the file to a different folder
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped

# %%
# %cd ./cool/
# !ls
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped/cool
# F0

# %%
# !cp -R F0 awesome
# !ls -a
#copy and rename a file
# Out:
# .  ..  awesome	F0

# %%
# !pwd
# !ls
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped/cool
# F0

# %%
# %cd ..
# !rm awesome
# !ls -a
#delete file
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped
# .     F111  F127  F141	F158  F173  F19   F204	F220  F25  F4	F55  F7   F84
# ..    F112  F128  F142	F159  F174  F190  F205	F221  F26  F40	F56  F70  F85
# cool  F113  F129  F144	F16   F175  F191  F206	F222  F27  F41	F57  F71  F86
# F0    F114  F13   F145	F160  F176  F192  F207	F223  F28  F42	F58  F72  F87
# F1    F115  F130  F146	F161  F177  F193  F208	F224  F29  F43	F59  F73  F88
# F10   F117  F131  F147	F162  F178  F194  F209	F225  F3   F44	F6   F74  F9
# F100  F118  F132  F148	F163  F179  F195  F210	F226  F30  F45	F60  F75  F90
# F101  F119  F133  F149	F164  F18   F196  F211	F227  F31  F46	F61  F76  F91
# F102  F12   F134  F15	F165  F180  F197  F212	F228  F32  F48	F62  F77  F93
# F104  F120  F135  F151	F166  F181  F198  F213	F229  F33  F49	F63  F78  F94
# F106  F121  F136  F152	F167  F182  F199  F214	F23   F34  F5	F64  F79  F95
# F107  F122  F137  F153	F168  F183  F2	  F215	F230  F35  F50	F65  F8   F96
# ...

# %%
# !rm -r cool/
# !ls -a
#delete folder
# Out:
# .     F112  F128  F142	F159  F174  F190  F205	F221  F26  F40	F56  F70  F85
# ..    F113  F129  F144	F16   F175  F191  F206	F222  F27  F41	F57  F71  F86
# F0    F114  F13   F145	F160  F176  F192  F207	F223  F28  F42	F58  F72  F87
# F1    F115  F130  F146	F161  F177  F193  F208	F224  F29  F43	F59  F73  F88
# F10   F117  F131  F147	F162  F178  F194  F209	F225  F3   F44	F6   F74  F9
# F100  F118  F132  F148	F163  F179  F195  F210	F226  F30  F45	F60  F75  F90
# F101  F119  F133  F149	F164  F18   F196  F211	F227  F31  F46	F61  F76  F91
# F102  F12   F134  F15	F165  F180  F197  F212	F228  F32  F48	F62  F77  F93
# F104  F120  F135  F151	F166  F181  F198  F213	F229  F33  F49	F63  F78  F94
# F106  F121  F136  F152	F167  F182  F199  F214	F23   F34  F5	F64  F79  F95
# F107  F122  F137  F153	F168  F183  F2	  F215	F230  F35  F50	F65  F8   F96
# F108  F123  F138  F154	F169  F185  F20   F216	F231  F36  F51	F66  F80  F97
# F109  F124  F139  F155	F170  F186  F200  F218	F232  F37  F52	F67  F81  F99
# ...

# %%
# !touch 8queen.jpg
#create or update a file

# %%
# !ln 8queen.jpg 1_pregnancy_length_analysis.ipynb
#physical link

# %%
# !ln -s 8queen.jpg 1_pregnancy_length_analysis.ipynb
#symbolic link

# %%
# !find ~ -size +30M
#find all files from home that are larger than 30Megabytes
# Out:
# /home/orysya/logs/1476474902/BlockData1000
# /home/orysya/logs/1476474902/BlockData100
# /home/orysya/Documents/DSE/ostus/DSE200/day_2_github_io_numpy_pandas/data_day2/cup98LRN.txt
# /home/orysya/Documents/DSE/ostus/DSE200/data/ThinkStatsData/2002FemResp.dat
# /home/orysya/Documents/DSE/ostus/DSE200/data/weather/make_covar.raw_256
# /home/orysya/Documents/DSE/ostus/.git/objects/84/f7aef09c69826248f6e1aa45b5a35eae23146a
# /home/orysya/Documents/DSE/ostus/.git/objects/39/cd53c7fcabdfb964882ad6353a66a9ca89ba14
# /home/orysya/Documents/DSE/DSE200-notebooks/data/ThinkStatsData/2002FemResp.dat
# /home/orysya/Documents/DSE/DSE200-notebooks/data/weather/make_covar.raw_256
# /home/orysya/Documents/DSE/DSE200-notebooks/.git/objects/pack/pack-162fbac709188d1e175ac6960a32759df59b99a8.pack
# /home/orysya/Downloads/basemap-1.0.7.tar.gz
# /home/orysya/Downloads/Anaconda2-4.1.0-Linux-x86_64.sh
# /home/orysya/Downloads/basemap-1.0.7/lib/mpl_toolkits/basemap/data/gshhs_f.dat
# ...

# %%
# !find -type f
#find files only
# Out:
# ./day_1_python_and_unix/.ipynb_checkpoints/3_python_basics_excercises-checkpoint.ipynb
# ./day_1_python_and_unix/.ipynb_checkpoints/2_python_basics-checkpoint.ipynb
# ./day_1_python_and_unix/.ipynb_checkpoints/1_pregnancy_length_analysis-checkpoint.ipynb
# ./day_1_python_and_unix/.ipynb_checkpoints/5_unix_exercises-checkpoint.ipynb
# ./day_1_python_and_unix/.ipynb_checkpoints/4_unix,_sys,_and_os-checkpoint.ipynb
# ./day_1_python_and_unix/LockFile.md
# ./day_1_python_and_unix/5_unix_exercises.ipynb
# ./day_1_python_and_unix/.DS_Store
# ./day_1_python_and_unix/8queen.jpg
# ./day_1_python_and_unix/5_unix_exercises_solutions.ipynb
# ./day_1_python_and_unix/3_python_basics_excercises.ipynb
# ./day_1_python_and_unix/._.DS_Store
# ./day_1_python_and_unix/3_python_basics_excercises_solutions.ipynb
# ./day_1_python_and_unix/4_unix,_sys,_and_os.ipynb
# ./day_1_python_and_unix/1_pregnancy_length_analysis.ipynb
# ./day_1_python_and_unix/2_python_basics.ipynb
# ./README.md
# ...

# %%
# !pwd
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks

# %%
# %cd ~/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped/
# !ls -a
i = 25
# !grep -r $i ./
#search for file names with occurance of the text
# Out:
# /home/orysya/Documents/DSE/DSE200-notebooks/data/NLTK/Chopped
# .     F114  F131  F149	F166  F183  F200  F22	F26  F42  F6   F76  F94
# ..    F115  F132  F15	F167  F185  F201  F220	F27  F43  F60  F77  F95
# F0    F117  F133  F151	F168  F186  F202  F221	F28  F44  F61  F78  F96
# F1    F118  F134  F152	F169  F187  F204  F222	F29  F45  F62  F79  F97
# F10   F119  F135  F153	F170  F189  F205  F223	F3   F46  F63  F8   F99
# F100  F12   F136  F154	F171  F19   F206  F224	F30  F48  F64  F80  sort_F114
# F101  F120  F137  F155	F172  F190  F207  F225	F31  F49  F65  F81  tmp
# F102  F121  F138  F156	F173  F191  F208  F226	F32  F5   F66  F82
# F104  F122  F139  F157	F174  F192  F209  F227	F33  F50  F67  F83
# F106  F123  F14   F158	F175  F193  F210  F228	F34  F51  F68  F84
# F107  F124  F140  F159	F176  F194  F211  F229	F35  F52  F69  F85
# F108  F125  F141  F16	F177  F195  F212  F23	F36  F53  F7   F86
# F109  F126  F142  F160	F178  F196  F213  F230	F37  F54  F70  F87
# ...

# %%
# !grep -E ted F109
# !grep -E the F122
#search start of lines with the word text
# Out:
#  1259 1266ted pra

# %%
# !grep -E 0-4 F124
#show lines containing numbers 0-4

# %%
# !grep -E a-z F124
#retrieve all lines with alphabetical letters

# %%
# !sort F114 #sort alphabetically

# %%
# !touch sort_F114
# !sort -o F114 sort_F114
#made a file sort_F114 & following sorting wrote result to sort_F114
# -r sort in reverse
# -R sort randomly
# sort -n sort numbers

# %%
# !cat F* | sort -n > together
# !cat together
# Out:
#     0    4The
#     4    8Fult
#     8   18on County
#    18   24Grand
#    24   37Jury said Fri
#    37   56day an investigatio
#    56   58n
#    58   60of
#    60   64 Atl
#    64   83anta's recent prima
#    83   88ry el
#    88   99ection prod
#    99  100u
#   100  110ced `` no
#   110  117evidenc
#   117  123e '' t
#   123  132hat any i
#   132  151rregularities took
#   151  155plac
#   155  161e . Th
#   161  168e jury
#   168  175further
#   175  178 sa
#   178  180id
#   180  181
#   181  183in
#   183  191 term-en
#   191  198d prese
#   198  199n
#   199  205tments
#   205  210 that
#   225  241tive Committee ,
#   241  242
#   242  264which had over-all cha
#   264  274rge of the
#   274  277 el
#   277  290ection , `` d
#   290  297eserves
#   297  299 t
#   299  305he pra
#   305  318ise and thank
#   318  319s
#   319  377 of the City of Atlanta '' for the manner in which the ele
#   377  384ction w
#   384  385a
#   385  416s conducted . The September-Oct
# ...

# %%
# !wc together
#nbr of line, nbr of words, byte size
# -l (lines), -w (words), -c (byte size), -m (number of characters)
# Out:
#  218  679 4019 together

# %%
# !wc -l together
# !wc -w together
# !wc -c together
# !wc -m together
#here byte size & number of characters is the same
# Out:
# 218 together
# 679 together
# 4019 together
# 4019 together

# %%
# !cat sort_F114
# !cut -c 1 sort_F114
#cut the characters 1 of each line
# -d (delimiter)
# -f (# of field to cut)
# Out:
# 00000000000111111111111122222222223
# 0

# %%
# !date #view & modify time
# !date "+%H" #if its 11pm it will show 23
# !date "+%H:%M:%Ss" #hours, minutes, seconds
# Out:
# Sat Oct 29 23:59:45 PDT 2016
# 23
# 23:59:46s

# %%
# !w
#who is logged on & what they are doing
# Out:
#  00:01:42 up 46 min,  1 user,  load average: 0.03, 0.12, 0.15
# USER     TTY      FROM             LOGIN@   IDLE   JCPU   PCPU WHAT
# orysya   tty7     :0               23:18   45:43  30.80s  0.21s /sbin/upstart -
